# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('Person 2/drowsy_cleaned_P2.csv')
df2 = pd.read_csv('Person 2/notdrowsy_cleaned_P2.csv')

# %%
df1.head(20)
# Out:
#      ear   mar
# 0   0.19  0.45
# 1   0.20  0.54
# 2   0.19  0.47
# 3   0.34  0.58
# 4   0.26  0.54
# 5   0.23  0.48
# 6   0.21  0.42
# 7   0.33  0.43
# 8   0.21  0.43
# 9   0.26  0.45
# 10  0.34  0.44
# 11  0.21  0.44
# 12  0.35  0.44
# 13  0.22  0.45
# 14  0.35  0.45
# 15  0.21  0.45
# 16  0.32  0.45
# 17  0.23  0.46
# 18  0.22  0.45
# 19  0.24  0.46

# %%
df2.head(20)
# Out:
#      ear   mar
# 0   0.33  0.40
# 1   0.32  0.39
# 2   0.32  0.43
# 3   0.30  0.45
# 4   0.31  0.49
# 5   0.30  0.47
# 6   0.30  0.46
# 7   0.30  0.47
# 8   0.31  0.46
# 9   0.31  0.46
# 10  0.31  0.46
# 11  0.29  0.47
# 12  0.29  0.47
# 13  0.29  0.46
# 14  0.28  0.46
# 15  0.27  0.46
# 16  0.29  0.46
# 17  0.31  0.45
# 18  0.29  0.47
# 19  0.31  0.49

# %%
plt.figure(figsize=(10,10))
plt.scatter(df1['mar'], df1['ear'], color='red',label='Drowsy')
plt.scatter(df2['mar'], df2['ear'], color='green', label='Not Drowsy')
plt.xlabel('MAR')
plt.ylabel('EAR')
plt.legend()
plt.savefig('Person 2/dr vs ndr.jpg',bbox_inches='tight')
plt.show()
